# %% [markdown]
# # Prueba de Apache Spark empleando Python
#
# Usaré la librería de PySpark para hacer pruebas de Apache Spark con Python.

# %%
# Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyspark as ps
